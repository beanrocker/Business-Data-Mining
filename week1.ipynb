# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Apigorn Pornrattanapitak"
print("Hello " +name+ " dsa")
# Out:
# Hello Apigorn Pornrattanapitak dsa

# %%
country = input("Where are you from = ")
# Out:
# Where are you from =  Nowhere

# %%
print("I am from " + country)
# Out:
# I am from Nowhere

# %%
age = int(input())
# Out:
#  20

# %%
print(age)
# Out:
# 20

# %%
x = age +10
print(x)
# Out:
# 30

# %%
a = 5
b = 2
c = a + b
print(c)
# Out:
# 7

# %%
pi = "3.14"
print(pi)
# Out:
# 3.14

# %%
print("Pi is " + pi)
# Out:
# Pi is 3.14

# %%
8//3,8/3
# Out:
# (2, 2.6666666666666665)

# %%
a = int(input("What is your A = "))
b = int(input("What is your B = "))
c = a + b
print(c)
# Out:
# What is your A =  1
# What is your B =  2
# 3

# %%
msg = "A" + "B"
print(msg)
# Out:
# AB

# %%
a = "gor"
a in "Apigorn ppp"
# Out:
# True

# %%
a = "Price"
b = 2000
print(a+" is %.2f" % b)
# Out:
# Price is 2000.00

# %%
a.upper()
# Out:
# 'PRICE'

# %%
a = "Apigorn Pornrattanapitak"
a.find("P")
# Out:
# 8

# %%
a = "apigorn ppp" + "\n"
a.rstrip()
# Out:
# 'apigorn ppp'

# %% [markdown]
# rstrip ตัดตัวอักษรพิเศษที่ติดมาด้วย

# %%
a = "Hello World"
a = a.split()
a
# Out:
# ['Hello', 'World']

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L.sort(reverse=True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
n = int(input())
for i in range(0,n+1):
    for j in range(0,i):
        print("x",end='')
    print()
# Out:
#  3
# x
# xx
# xxx
